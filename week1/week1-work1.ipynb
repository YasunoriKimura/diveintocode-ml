# %%
#　べき乗の算術演算子を使用した計算方法と計算速度

import time
start = time.time()

# べき乗を使った計算方法
thickness = 0.00008

folded_thickness = thickness*2**43
print("厚さ： {:.2f}キロメートル".format(folded_thickness / 1000))

elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# 厚さ： 703687.44キロメートル
# time : 0.000263214111328125[s]

# %%
#　for文を使用した計算方法と計算速度

import time
start = time.time()

#for文を使った計算方法
thickness = 0.00008

for i in range(43):
    thickness *= 2

print("厚さ： {:.2f}キロメートル".format(thickness/1000))

elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# 厚さ： 703687.44キロメートル
# time : 0.0003991127014160156[s]

# %%
#　for文を使用した計算方法折れ線グラフ

import matplotlib.pyplot as plt
# %matplotlib inline

thickness = 0.00008
thickness_list = [thickness]

for i in range(43):
    thickness *= 2
    thickness_list.append(thickness)

print("配列の要素数 : {}".format(len(thickness_list)))

plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.plot(thickness_list)
# Out:
# 配列の要素数 : 44

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

thickness = 0.00008
thickness_list = [thickness]

for i in range(43):
    thickness *= 2
    thickness_list.append(thickness)

"""
赤い折れ線グラフを表示する。
"""
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.plot(thickness_list, color='red')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

thickness = 0.00008
thickness_list = [thickness]

for i in range(43):
    thickness *= 2
    thickness_list.append(thickness)

"""
赤い折れ線グラフを表示する。
"""
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.plot(thickness_list, color='green', linewidth=3, linestyle='dashed')
